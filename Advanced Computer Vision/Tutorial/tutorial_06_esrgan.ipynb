# %% [markdown]
# # ESRGAN
# In this tutorial, you will learn:
# - An enhanced super-resolution algorithm ([ESRGAN](https://arxiv.org/abs/1809.00219)) for better visual quality.
# - [Deep Network Interpolation](https://arxiv.org/abs/1811.10515) (DNI), a technique for balancing PSNR-oriented outputs and perceptual restorations.
#
# Let's start!

# %% [markdown]
# # Install MMEditing

# %%
# Install openmim for installation of mmcv-full
# !pip install openmim

# Install mmcv-full thus we could use CUDA operators
# !mim install mmcv-full

# Clone MMEditing
# !rm -rf mmediting
# !git clone https://github.com/open-mmlab/mmediting.git
# %cd mmediting

# Install MMEditing
# !pip install -v -e .
# Out:
# Collecting openmim
#   Downloading openmim-0.1.5.tar.gz (35 kB)
# Requirement already satisfied: Click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from openmim) (7.1.2)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from openmim) (2.23.0)
# Collecting model-index
#   Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from openmim) (1.3.5)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from openmim) (0.8.9)
# Requirement already satisfied: markdown in /usr/local/lib/python3.7/dist-packages (from model-index->openmim) (3.3.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from model-index->openmim) (3.13)
# Collecting ordered-set
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown->model-index->openmim) (4.11.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown->model-index->openmim) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown->model-index->openmim) (3.7.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->openmim) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->openmim) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->openmim) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->openmim) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->openmim) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->openmim) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->openmim) (2.10)
# Building wheels for collected packages: openmim
#   Building wheel for openmim (setup.py) ... done
#   Created wheel for openmim: filename=openmim-0.1.5-py2.py3-none-any.whl size=42503 sha256=03288db9057cab9243fd4d762383425ac09e6e3c38a17c167d6f7ca2714201bc
#   Stored in directory: /root/.cache/pip/wheels/16/8b/e1/bdebbbc687aa50224a5ce46fe97a040a0c59f92b34bfc750b6
# Successfully built openmim
# Installing collected packages: ordered-set, model-index, colorama, openmim
# Successfully installed colorama-0.4.4 model-index-0.1.11 openmim-0.1.5 ordered-set-4.1.0
# installing mmcv-full from wheel.
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu111/torch1.10.0/index.html
# Collecting mmcv-full==1.4.6
#   Downloading https://download.openmmlab.com/mmcv/dist/cu111/torch1.10.0/mmcv_full-1.4.6-cp37-cp37m-manylinux1_x86_64.whl (46.0 MB)
#      |████████████████████████████████| 46.0 MB 328 kB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from mmcv-full==1.4.6) (7.1.2)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.7/dist-packages (from mmcv-full==1.4.6) (4.1.2.30)
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from mmcv-full==1.4.6) (21.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from mmcv-full==1.4.6) (3.13)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mmcv-full==1.4.6) (1.21.5)
# Collecting yapf
#   Downloading yapf-0.32.0-py2.py3-none-any.whl (190 kB)
#      |████████████████████████████████| 190 kB 5.2 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->mmcv-full==1.4.6) (3.0.7)
# Installing collected packages: yapf, addict, mmcv-full
# Successfully installed addict-2.4.0 mmcv-full-1.4.6 yapf-0.32.0
# Successfully installed mmcv-full.
# Cloning into 'mmediting'...
# remote: Enumerating objects: 10110, done.
# remote: Counting objects: 100% (783/783), done.
# remote: Compressing objects: 100% (495/495), done.
# remote: Total 10110 (delta 364), reused 556 (delta 268), pack-reused 9327
# Receiving objects: 100% (10110/10110), 6.07 MiB | 20.39 MiB/s, done.
# Resolving deltas: 100% (6675/6675), done.
# /content/mmediting
# Using pip 21.1.3 from /usr/local/lib/python3.7/dist-packages/pip (python 3.7)
# Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/include/python3.7/UNKNOWN
# sysconfig: /usr/include/python3.7m/UNKNOWN
# Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/bin
# sysconfig: /usr/bin
# Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local
# sysconfig: /usr
# Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Non-user install because site-packages writeable
# Created temporary directory: /tmp/pip-ephem-wheel-cache-vh5n9ba4
# Created temporary directory: /tmp/pip-req-tracker-i5hso4i9
# Initialized build tracking at /tmp/pip-req-tracker-i5hso4i9
# Created build tracker: /tmp/pip-req-tracker-i5hso4i9
# Entered build tracker: /tmp/pip-req-tracker-i5hso4i9
# Created temporary directory: /tmp/pip-install-3oxlzjyj
# Obtaining file:///content/mmediting
#   Added file:///content/mmediting to build tracker '/tmp/pip-req-tracker-i5hso4i9'
#     Running setup.py (path:/content/mmediting/setup.py) egg_info for package from file:///content/mmediting
#     Created temporary directory: /tmp/pip-pip-egg-info-r5ey922x
#     Running command python setup.py egg_info
#     running egg_info
#     creating /tmp/pip-pip-egg-info-r5ey922x/mmedit.egg-info
#     writing /tmp/pip-pip-egg-info-r5ey922x/mmedit.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-r5ey922x/mmedit.egg-info/dependency_links.txt
#     writing requirements to /tmp/pip-pip-egg-info-r5ey922x/mmedit.egg-info/requires.txt
#     writing top-level names to /tmp/pip-pip-egg-info-r5ey922x/mmedit.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-r5ey922x/mmedit.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching 'mmedit/.mim/VERSION'
#     warning: no files found matching 'mmedit/.mim/model-index.yml'
#     warning: no files found matching '*.py' under directory 'mmedit/.mim/configs'
#     warning: no files found matching '*.yml' under directory 'mmedit/.mim/configs'
#     warning: no files found matching '*.sh' under directory 'mmedit/.mim/tools'
#     warning: no files found matching '*.py' under directory 'mmedit/.mim/tools'
#     warning: no files found matching '*.py' under directory 'mmedit/.mim/demo'
#     adding license file 'LICENSE'
#     writing manifest file '/tmp/pip-pip-egg-info-r5ey922x/mmedit.egg-info/SOURCES.txt'
#   Source in /content/mmediting has version 0.13.0, which satisfies requirement mmedit==0.13.0 from file:///content/mmediting
#   Removed mmedit==0.13.0 from file:///content/mmediting from build tracker '/tmp/pip-req-tracker-i5hso4i9'
# Requirement already satisfied: lmdb in /usr/local/lib/python3.7/dist-packages (from mmedit==0.13.0) (0.99)
# Requirement already satisfied: mmcv-full>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from mmedit==0.13.0) (1.4.6)
# Requirement already satisfied: opencv-python<=4.5.4.60 in /usr/local/lib/python3.7/dist-packages (from mmedit==0.13.0) (4.1.2.30)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from mmedit==0.13.0) (0.18.3)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from mmedit==0.13.0) (2.8.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.7/dist-packages (from mmedit==0.13.0) (0.32.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from mmcv-full>=1.3.1->mmedit==0.13.0) (21.3)
# Requirement already satisfied: addict in /usr/local/lib/python3.7/dist-packages (from mmcv-full>=1.3.1->mmedit==0.13.0) (2.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mmcv-full>=1.3.1->mmedit==0.13.0) (1.21.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from mmcv-full>=1.3.1->mmedit==0.13.0) (3.13)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from mmcv-full>=1.3.1->mmedit==0.13.0) (7.1.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->mmcv-full>=1.3.1->mmedit==0.13.0) (3.0.7)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->mmedit==0.13.0) (2021.11.2)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->mmedit==0.13.0) (1.4.1)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->mmedit==0.13.0) (3.2.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->mmedit==0.13.0) (1.2.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->mmedit==0.13.0) (2.6.3)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->mmedit==0.13.0) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->mmedit==0.13.0) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->mmedit==0.13.0) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->mmedit==0.13.0) (1.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib!=3.0.0,>=2.0.0->scikit-image->mmedit==0.13.0) (1.15.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->mmedit==0.13.0) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->mmedit==0.13.0) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->mmedit==0.13.0) (0.6.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->mmedit==0.13.0) (3.17.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->mmedit==0.13.0) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->mmedit==0.13.0) (1.44.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->mmedit==0.13.0) (1.8.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->mmedit==0.13.0) (57.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->mmedit==0.13.0) (2.23.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->mmedit==0.13.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->mmedit==0.13.0) (3.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->mmedit==0.13.0) (0.37.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->mmedit==0.13.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->mmedit==0.13.0) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->mmedit==0.13.0) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->mmedit==0.13.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard->mmedit==0.13.0) (4.11.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->mmedit==0.13.0) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->mmedit==0.13.0) (3.10.0.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->mmedit==0.13.0) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->mmedit==0.13.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->mmedit==0.13.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->mmedit==0.13.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->mmedit==0.13.0) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->mmedit==0.13.0) (3.2.0)
# Created temporary directory: /tmp/pip-unpack-h3ndwx_s
# Installing collected packages: mmedit
#   Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/lib/python3.7/dist-packages
#   sysconfig: /usr/lib/python3.7/site-packages
#   Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/lib/python3.7/dist-packages
#   sysconfig: /usr/lib/python3.7/site-packages
#   Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/include/python3.7/mmedit
#   sysconfig: /usr/include/python3.7m/mmedit
#   Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/bin
#   sysconfig: /usr/bin
#   Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local
#   sysconfig: /usr
#   Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = None
#   Running setup.py develop for mmedit
#     Running command /usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/content/mmediting/setup.py'"'"'; __file__='"'"'/content/mmediting/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' develop --no-deps
#     running develop
#     running egg_info
#     creating mmedit.egg-info
#     writing mmedit.egg-info/PKG-INFO
#     writing dependency_links to mmedit.egg-info/dependency_links.txt
#     writing requirements to mmedit.egg-info/requires.txt
#     writing top-level names to mmedit.egg-info/top_level.txt
#     writing manifest file 'mmedit.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching 'mmedit/.mim/VERSION'
#     adding license file 'LICENSE'
#     writing manifest file 'mmedit.egg-info/SOURCES.txt'
#     running build_ext
#     Creating /usr/local/lib/python3.7/dist-packages/mmedit.egg-link (link to .)
#     Adding mmedit 0.13.0 to easy-install.pth file
#
#     Installed /content/mmediting
# Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/include/python3.7/UNKNOWN
# sysconfig: /usr/include/python3.7m/UNKNOWN
# Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/bin
# sysconfig: /usr/bin
# Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local
# sysconfig: /usr
# Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Successfully installed mmedit-0.13.0
# Removed build tracker: '/tmp/pip-req-tracker-i5hso4i9'

# %%
# Check Pytorch installation
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())

# Check MMEditing installation
import mmedit
print(mmedit.__version__)
# Out:
# 1.10.0+cu111 True
# 0.13.0

# %% [markdown]
# # SRCNN Recap
# We have already run SRCNN and familiarized ourselves with it.
#
# SRCNN is a very simple CNN-based method for super-resolution. It contains only three convolution layers, each performing a function:
#
# - The first convolution layer performs feature extraction;
# - The second convolution layer with activation functions performs non-linear mapping;
# - The last convolution layer converts the features back to images by reconstruction.
#
# With increasing model capacity and improved model structures, will the model perform better?
#
# Now let's try a much larger model.

# %% [markdown]
# # From SRCNN to A Larger Model
# Here, we choose the RRDB-Net, which is short for Residual in Residual Dense Block Network.
#
# Let's fist look at its network structure! Just take a glance at it. You are not required to know every detail of it
#
# The overall structure is as follows:
#
# ![RRDB-Net](https://raw.githubusercontent.com/xinntao/public-figures/master/MMEditing-Tutorial/RRDB-Net.png)
#
# Inside each basic block is the RRDB, which combines the merits of ResNet and DenseNet:
#
# ![RRDB](https://raw.githubusercontent.com/xinntao/public-figures/master/MMEditing-Tutorial/RRDB.png)

# %% [markdown]
# Now let's run a pre-trained RRDB-Net with baboon!
#
# First, download pre-trained models and data.

# %%
# Download pre-trained models
# !mkdir checkpoints
# !wget -c https://openmmlab.oss-accelerate.aliyuncs.com/mmediting/restorers/esrgan/esrgan_psnr_x4c64b23g32_1x16_1000k_div2k_20200420-bf5c993c.pth \
    -O checkpoints/esrgan_psnr_x4c64b23g32_1x16_1000k_div2k_20200420-bf5c993c.pth
# !wget -c https://openmmlab.oss-accelerate.aliyuncs.com/mmediting/restorers/srcnn/srcnn_x4k915_1x16_1000k_div2k_20200608-4186f232.pth \
    -O checkpoints/srcnn_x4k915_1x16_1000k_div2k_20200608-4186f232.pth
# !wget -c https://openmmlab.oss-accelerate.aliyuncs.com/mmediting/restorers/esrgan/esrgan_x4c64b23g32_1x16_400k_div2k_20200508-f8ccaf3b.pth \
    -O checkpoints/esrgan_x4c64b23g32_1x16_400k_div2k_20200508-f8ccaf3b.pth
# Out:
# --2022-03-20 07:14:29--  https://openmmlab.oss-accelerate.aliyuncs.com/mmediting/restorers/esrgan/esrgan_psnr_x4c64b23g32_1x16_1000k_div2k_20200420-bf5c993c.pth
# Resolving openmmlab.oss-accelerate.aliyuncs.com (openmmlab.oss-accelerate.aliyuncs.com)... 47.252.96.35
# Connecting to openmmlab.oss-accelerate.aliyuncs.com (openmmlab.oss-accelerate.aliyuncs.com)|47.252.96.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66914297 (64M) [application/octet-stream]
# Saving to: ‘checkpoints/esrgan_psnr_x4c64b23g32_1x16_1000k_div2k_20200420-bf5c993c.pth’
#
# checkpoints/esrgan_ 100%[===================>]  63.81M  8.10MB/s    in 8.1s
#
# 2022-03-20 07:14:38 (7.89 MB/s) - ‘checkpoints/esrgan_psnr_x4c64b23g32_1x16_1000k_div2k_20200420-bf5c993c.pth’ saved [66914297/66914297]
#
# --2022-03-20 07:14:38--  https://openmmlab.oss-accelerate.aliyuncs.com/mmediting/restorers/srcnn/srcnn_x4k915_1x16_1000k_div2k_20200608-4186f232.pth
# Resolving openmmlab.oss-accelerate.aliyuncs.com (openmmlab.oss-accelerate.aliyuncs.com)... 47.252.96.35
# Connecting to openmmlab.oss-accelerate.aliyuncs.com (openmmlab.oss-accelerate.aliyuncs.com)|47.252.96.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85911 (84K) [application/octet-stream]
# Saving to: ‘checkpoints/srcnn_x4k915_1x16_1000k_div2k_20200608-4186f232.pth’
#
# checkpoints/srcnn_x 100%[===================>]  83.90K  --.-KB/s    in 0.06s
#
# 2022-03-20 07:14:39 (1.36 MB/s) - ‘checkpoints/srcnn_x4k915_1x16_1000k_div2k_20200608-4186f232.pth’ saved [85911/85911]
#
# --2022-03-20 07:14:39--  https://openmmlab.oss-accelerate.aliyuncs.com/mmediting/restorers/esrgan/esrgan_x4c64b23g32_1x16_400k_div2k_20200508-f8ccaf3b.pth
# Resolving openmmlab.oss-accelerate.aliyuncs.com (openmmlab.oss-accelerate.aliyuncs.com)... 47.252.96.35
# Connecting to openmmlab.oss-accelerate.aliyuncs.com (openmmlab.oss-accelerate.aliyuncs.com)|47.252.96.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205049018 (196M) [application/octet-stream]
# Saving to: ‘checkpoints/esrgan_x4c64b23g32_1x16_400k_div2k_20200508-f8ccaf3b.pth’
#
# checkpoints/esrgan_ 100%[===================>] 195.55M  8.99MB/s    in 22s
#
# 2022-03-20 07:15:03 (8.69 MB/s) - ‘checkpoints/esrgan_x4c64b23g32_1x16_400k_div2k_20200508-f8ccaf3b.pth’ saved [205049018/205049018]

# %%
# download data
# !mkdir data
# !wget https://raw.githubusercontent.com/open-mmlab/mmediting/master/tests/data/lq/baboon_x4.png
# !wget https://raw.githubusercontent.com/open-mmlab/mmediting/master/tests/data/gt/baboon.png
# !wget https://raw.githubusercontent.com/xinntao/public-figures/master/MMEditing-Tutorial/zebra_x4.png
# !mv baboon_x4.png ./data/baboon_x4.png
# !mv baboon.png ./data/baboon.png
# !mv zebra_x4.png ./data/zebra_x4.png
# Out:
# --2022-03-20 07:15:07--  https://raw.githubusercontent.com/open-mmlab/mmediting/master/tests/data/lq/baboon_x4.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33918 (33K) [image/png]
# Saving to: ‘baboon_x4.png’
#
# baboon_x4.png       100%[===================>]  33.12K  --.-KB/s    in 0.002s
#
# 2022-03-20 07:15:07 (14.3 MB/s) - ‘baboon_x4.png’ saved [33918/33918]
#
# --2022-03-20 07:15:07--  https://raw.githubusercontent.com/open-mmlab/mmediting/master/tests/data/gt/baboon.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 553249 (540K) [image/png]
# Saving to: ‘baboon.png’
#
# baboon.png          100%[===================>] 540.28K  --.-KB/s    in 0.04s
#
# 2022-03-20 07:15:08 (13.2 MB/s) - ‘baboon.png’ saved [553249/553249]
#
# --2022-03-20 07:15:08--  https://raw.githubusercontent.com/xinntao/public-figures/master/MMEditing-Tutorial/zebra_x4.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33881 (33K) [image/png]
# Saving to: ‘zebra_x4.png’
#
# zebra_x4.png        100%[===================>]  33.09K  --.-KB/s    in 0.002s
#
# 2022-03-20 07:15:08 (13.7 MB/s) - ‘zebra_x4.png’ saved [33881/33881]

# %% [markdown]
# # Inference with RRDB-Net in MMEditing

# %%
! mkdir results
# Inference with SRCNN
! python demo/restoration_demo.py configs/restorers/srcnn/srcnn_x4k915_g1_1000k_div2k.py checkpoints/srcnn_x4k915_1x16_1000k_div2k_20200608-4186f232.pth data/baboon_x4.png results/baboon_SRCNN.png
# Inference with RRDB-Net
! python demo/restoration_demo.py configs/restorers/esrgan/esrgan_psnr_x4c64b23g32_g1_1000k_div2k.py checkpoints/esrgan_psnr_x4c64b23g32_1x16_1000k_div2k_20200420-bf5c993c.pth data/baboon_x4.png results/baboon_RRDB-Net.png
# Out:
# load checkpoint from local path: checkpoints/srcnn_x4k915_1x16_1000k_div2k_20200608-4186f232.pth
# load checkpoint from local path: checkpoints/esrgan_psnr_x4c64b23g32_1x16_1000k_div2k_20200420-bf5c993c.pth

# %% [markdown]
# Let's look inside the codes!
#
# We will write python codes with MMEditing high-level APIs to perform super-resolution.

# %%
import mmcv
import torch
from mmedit.apis import init_model, restoration_inference
from mmedit.core import tensor2img

# Configurations 
config = 'configs/restorers/esrgan/esrgan_psnr_x4c64b23g32_g1_1000k_div2k.py'
checkpoint = 'checkpoints/esrgan_psnr_x4c64b23g32_1x16_1000k_div2k_20200420-bf5c993c.pth'
img_path = 'data/baboon_x4.png'
save_path = 'results/baboon_RRDB-Net.png'

# Initilize model
model = init_model(
        config, checkpoint, device=torch.device('cuda'))

# Inference
output = restoration_inference(model, img_path)

# Change the network output to images
output = tensor2img(output)

# Save images
mmcv.imwrite(output, save_path)
# Out:
# load checkpoint from local path: checkpoints/esrgan_psnr_x4c64b23g32_1x16_1000k_div2k_20200420-bf5c993c.pth
# True

# %% [markdown]
# # Visualize Outputs

# %%
# %matplotlib inline 
import mmcv
import matplotlib.pyplot as plt

# Load LR and GT images
img_lr = mmcv.imread('./data/baboon_x4.png', channel_order='rgb')  # read LR image
img_gt = mmcv.imread('./data/baboon.png', channel_order='rgb')  # read GT (Ground-Truth) image

# Load SRCNN and RRDB-Net results
img_srcnn = mmcv.imread('./results/baboon_SRCNN.png', channel_order='rgb')
img_rrdb_net = mmcv.imread('./results/baboon_RRDB-Net.png', channel_order='rgb')

# Plot figures
fig = plt.figure(figsize=(18, 16))
ax1 = fig.add_subplot(2, 2, 1)  # 2 rows, 2 columns, the top left image  
ax1.title.set_text('LR')
ax1.axis('off')
ax2 = fig.add_subplot(2, 2, 2)  # 2 rows, 2 columns, the top right image  
ax2.title.set_text('SRCNN')
ax2.axis('off')
ax3 = fig.add_subplot(2, 2, 3)  # 2 rows, 2 columns, the top right image  
ax3.title.set_text('RRDB')
ax3.axis('off')
ax4 = fig.add_subplot(2, 2, 4)  # 2 rows, 2 columns, the bottom right image  
ax4.title.set_text('GT')
ax4.axis('off')
ax1.imshow(img_lr)
ax2.imshow(img_srcnn)
ax3.imshow(img_rrdb_net)
ax4.imshow(img_gt)

# %% [markdown]
# The top left is the input low-resolution image. The top right is the SRCNN output. The bottom left is the larger RRDB-Net result, while the bottom right is the ground truth.
#
# These results suggest that we can recover better results with sharper edges by using a model with a higher capacity and improved structure.

# %% [markdown]
# However, even though the output of RRDB-Net has **sharper edges** than that of SRCNN, the **textures of the baboon** is still unsatisfactory compared to the ground truth, especially the whiskers.
#
# For human beings, we prefer outputs with higher perceptual quality more than PSNR-oriented outputs.

# %% [markdown]
# # Perceptual Quality
#
# Let's try ESRGAN for better perceptual quality.
#
# The network structure is the same as that of RRDB-net. However, it is trained with [GAN loss](https://arxiv.org/abs/1609.04802) and [perceptual loss](https://arxiv.org/abs/1603.08155).

# %%
# Configuations 
config = 'configs/restorers/esrgan/esrgan_x4c64b23g32_g1_400k_div2k.py'
checkpoint = 'checkpoints/esrgan_x4c64b23g32_1x16_400k_div2k_20200508-f8ccaf3b.pth'
img_path = 'data/baboon_x4.png'
save_path = 'results/baboon_ESRGAN.png'

# Initilize model
model = init_model(
        config, checkpoint, device=torch.device('cuda'))

# Inference
output = restoration_inference(model, img_path)
output = tensor2img(output)

mmcv.imwrite(output, save_path)

# Visualize 
img_esrgan = mmcv.imread('results/baboon_ESRGAN.png', channel_order='rgb')

fig = plt.figure(figsize=(18, 16))
ax1 = fig.add_subplot(2, 2, 1)
ax1.title.set_text('RRDB')
ax1.axis('off')
ax2 = fig.add_subplot(2, 2, 2)
ax2.title.set_text('ESRGAN')
ax2.axis('off')

ax1.imshow(img_rrdb_net)
ax2.imshow(img_esrgan)
# Out:
# 2022-03-20 07:18:57,356 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]
# load checkpoint from local path: checkpoints/esrgan_x4c64b23g32_1x16_400k_div2k_20200508-f8ccaf3b.pth

# %% [markdown]
# Compare the picture on the left and on the right. Is the new outcome much improved? This is the magic of generative adversarial network and perceptual loss!

# %% [markdown]
# ## Metrics
#
# Usually we use some metrics to measure the image quality after super-resolution. Here we introduce two metrics: PSNR and NIQE.

# %% [markdown]
# ### PSNR (Peak Signal-to-Noise Ratio)
#
# We usually measure the output with Peak Signal-to-Noise Ratio, often abbreviated PSNR. It is an engineering term for the ratio between the maximum possible power of a signal and the power of corrupting noise that affects the fidelity of its representation.
#
# The formulation is as follows:
# Given a m×n image I and its approximation K, MSE is defined as:
#
# ![](https://wikimedia.org/api/rest_v1/media/math/render/svg/3a34719b4f391dba26b3e8e4460b7595d62eece4)
#
# The PSNR (in dB) is defined as:
#
# ![](https://wikimedia.org/api/rest_v1/media/math/render/svg/fc22801ed1232ff1231c4156b589de5c32063a8a)
#
# Here, MAX is the maximum possible pixel value of the image. When the pixels are represented using 8 bits per sample, this is 255.

# %% [markdown]
# We can calculate the PSNR of each image using MMEditing metric functions.

# %%
from mmedit.core.evaluation import psnr, niqe
# Bicubic images
h, w, c = img_lr.shape
img_bic, _, _ = mmcv.imresize(img_lr, (w * 4, h * 4), 'bicubic')
psnr_bic = psnr(img_bic, img_gt, crop_border=4, input_order='HWC')
print('PSNR for bicubic image: ', psnr_bic)
# Out:
# PSNR for bicubic image:  20.219525478550597

# %%
# PSNRs for SRCNN and RRDB-Net
psnr_srcnn = psnr(img_srcnn, img_gt, crop_border=4, input_order='HWC')
psnr_rrdb_net = psnr(img_rrdb_net, img_gt, crop_border=4, input_order='HWC')
psnr_esrgan = psnr(img_esrgan, img_gt, crop_border=4, input_order='HWC')
print('PSNR for SRCNN image: ', psnr_srcnn)
print('PSNR for RRDB-Net image: ', psnr_rrdb_net)
print('PSNR for ESRGAN: ', psnr_esrgan)
# Out:
# PSNR for SRCNN image:  20.710675934626643
# PSNR for RRDB-Net image:  21.073739904832536
# PSNR for ESRGAN:  18.613525513212707

# %% [markdown]
# We can see that RRDB-Net output has a higher PSNR than SRCNN output. Interestingly, the PSNR of ESRGAN output is lower than that of RRDB-Net and SRCNN output, even though ESRGAN has a more visual-pleasing effect.
#
# So, PSNR is not a good metric for reflecting the perceptual quality.
#
# Therefore, we introduce another metric that is able to reflect the perceptual quality of super-resolution - NIQE.

# %% [markdown]
# ### NIQE (Natural Image Quality Evaluator)
# NIQE is a no-reference image quality evaluator that assesses image quality without knowledge of anticipated distortions or human opinions of them. The quality of the distorted image is expressed as a simple distance metric between the
# model statistics and those of the distorted image. Such a model has great potential to be
# applied in unconstrained environments.
#
# Paper: [Making a "Completely Blind" Image Quality Analyzer](http://live.ece.utexas.edu/research/Quality/niqe_spl.pdf)
#
# We can also call NIQE functions using MMEditing APIs.

# %%
# Calculate NIQE of ESRGAN
niqe_bic = niqe(img_bic, crop_border=4, input_order='HWC')
niqe_srcnn = niqe(img_srcnn, crop_border=4, input_order='HWC')
niqe_rreb_net = niqe(img_rrdb_net, crop_border=4, input_order='HWC')
niqe_esrgan = niqe(img_esrgan, crop_border=4, input_order='HWC')
niqe_gt = niqe(img_gt, crop_border=4, input_order='HWC')

print('NIQE for bicubic image: ', niqe_bic)
print('NIQE for SRCNN image: ', niqe_srcnn)
print('NIQE for RRDB-Net image: ', niqe_rreb_net)
print('NIQE for ESRGAN image: ', niqe_esrgan)
print('NIQE for GT image: ', niqe_gt)
# Out:
# NIQE for bicubic image:  10.670614001608707
# NIQE for SRCNN image:  7.376164875363234
# NIQE for RRDB-Net image:  4.902841588549793
# NIQE for ESRGAN image:  2.9982140686077066
# NIQE for GT image:  6.0668295146412525

# %% [markdown]
# The ESRGAN result could produce lower NIQE, indicating better visual quality.
#
# However, this metric is also not perfect. From the above values, we can also see that the GT image has a higher NIQE value than outputs of RRDB-Net and ESRGAN, which is not reasonable.

# %% [markdown]
# # Try it Yourself!
#
# You can use other images from the dataset and super-resolve them~

# %%
# Inference with SRCNN
! python demo/restoration_demo.py configs/restorers/srcnn/srcnn_x4k915_g1_1000k_div2k.py checkpoints/srcnn_x4k915_1x16_1000k_div2k_20200608-4186f232.pth data/zebra_x4.png results/zebra_SRCNN.png
# Inference with RRDB-Net
! python demo/restoration_demo.py configs/restorers/esrgan/esrgan_psnr_x4c64b23g32_g1_1000k_div2k.py checkpoints/esrgan_psnr_x4c64b23g32_1x16_1000k_div2k_20200420-bf5c993c.pth data/zebra_x4.png results/zebra_RRDB-Net.png
# Inference with ESRGAN
! python demo/restoration_demo.py configs/restorers/esrgan/esrgan_x4c64b23g32_g1_400k_div2k.py checkpoints/esrgan_x4c64b23g32_1x16_400k_div2k_20200508-f8ccaf3b.pth data/zebra_x4.png results/zebra_ESRGAN.png
# Out:
# load checkpoint from local path: checkpoints/srcnn_x4k915_1x16_1000k_div2k_20200608-4186f232.pth
# load checkpoint from local path: checkpoints/esrgan_psnr_x4c64b23g32_1x16_1000k_div2k_20200420-bf5c993c.pth
# 2022-03-20 07:25:05,410 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: checkpoints/esrgan_x4c64b23g32_1x16_400k_div2k_20200508-f8ccaf3b.pth

# %%
# Load LR and GT images
zebra_lr = mmcv.imread('./data/zebra_x4.png', channel_order='rgb')  # read GT (Ground-Truth) image
# Load SRCNN and RRDB-Net results
zebra_srcnn = mmcv.imread('./results/zebra_SRCNN.png', channel_order='rgb')
zebra_rrdb_net = mmcv.imread('./results/zebra_RRDB-Net.png', channel_order='rgb')
# Load ESRGAN result
zebra_esrgan = mmcv.imread('./results/zebra_ESRGAN.png', channel_order='rgb')

# Plot figures
fig = plt.figure(figsize=(18, 16))
ax1 = fig.add_subplot(2, 2, 1)  # 2 rows, 2 columns, the top left image  
ax1.axis('off')
ax2 = fig.add_subplot(2, 2, 2)  # 2 rows, 2 columns, the top right image  
ax2.axis('off')
ax3 = fig.add_subplot(2, 2, 3)  # 2 rows, 2 columns, the top right image  
ax3.axis('off')
ax4 = fig.add_subplot(2, 2, 4)  # 2 rows, 2 columns, the bottom right image  
ax4.axis('off')
ax1.imshow(zebra_lr)
ax2.imshow(zebra_srcnn)
ax3.imshow(zebra_rrdb_net)
ax4.imshow(zebra_esrgan)

# %% [markdown]
# # Balance PSNR-oriented Results and Perceptual Quality

# %% [markdown]
# How to balance the PSNR-oriented results and GAN effects to meet various user flavors and application scenarios?
#
# We introduce a simple yet effective technique to achieve this goal - Deep Network Interpolation.
#
# It actually interplotes two networks in their parameter space!
#
# Sounds crazy? Let's look at what it does!

# %% [markdown]
# This is the illustration of Deep Network Interpolation (DNI).
#
# Provided with a model for a particular effect A, we fine-tune it to realize another relevant effect B.
#
# DNI applies linear interpolation for all the corresponding parameters of these two deep networks.
#
# Various interpolated models can then be derived by a controllable interpolation coefficient.
#
# Performing feed-forward operations on these interpolated models using the same input allows us to produce output with a continuous transition between the different effects A and B.

# %% [markdown]
# ![](https://raw.githubusercontent.com/xinntao/public-figures/master/MMEditing-Tutorial/DNI_1.jpg)
#
# ![](https://raw.githubusercontent.com/xinntao/public-figures/master/MMEditing-Tutorial/DNI_2.jpg)

# %% [markdown]
# Let's first look at the parameters of the network.

# %%
import torch
net_rrdb_net = torch.load('checkpoints/esrgan_psnr_x4c64b23g32_1x16_1000k_div2k_20200420-bf5c993c.pth')

for key, value in net_rrdb_net['state_dict'].items():
  print(key)
# Out:
# generator.conv_first.weight
# generator.conv_first.bias
# generator.body.0.rdb1.conv1.weight
# generator.body.0.rdb1.conv1.bias
# generator.body.0.rdb1.conv2.weight
# generator.body.0.rdb1.conv2.bias
# generator.body.0.rdb1.conv3.weight
# generator.body.0.rdb1.conv3.bias
# generator.body.0.rdb1.conv4.weight
# generator.body.0.rdb1.conv4.bias
# generator.body.0.rdb1.conv5.weight
# generator.body.0.rdb1.conv5.bias
# generator.body.0.rdb2.conv1.weight
# generator.body.0.rdb2.conv1.bias
# generator.body.0.rdb2.conv2.weight
# generator.body.0.rdb2.conv2.bias
# generator.body.0.rdb2.conv3.weight
# generator.body.0.rdb2.conv3.bias
# generator.body.0.rdb2.conv4.weight
# generator.body.0.rdb2.conv4.bias
# generator.body.0.rdb2.conv5.weight
# generator.body.0.rdb2.conv5.bias
# generator.body.0.rdb3.conv1.weight
# generator.body.0.rdb3.conv1.bias
# generator.body.0.rdb3.conv2.weight
# generator.body.0.rdb3.conv2.bias
# generator.body.0.rdb3.conv3.weight
# generator.body.0.rdb3.conv3.bias
# generator.body.0.rdb3.conv4.weight
# generator.body.0.rdb3.conv4.bias
# generator.body.0.rdb3.conv5.weight
# generator.body.0.rdb3.conv5.bias
# generator.body.1.rdb1.conv1.weight
# generator.body.1.rdb1.conv1.bias
# generator.body.1.rdb1.conv2.weight
# generator.body.1.rdb1.conv2.bias
# generator.body.1.rdb1.conv3.weight
# generator.body.1.rdb1.conv3.bias
# generator.body.1.rdb1.conv4.weight
# generator.body.1.rdb1.conv4.bias
# generator.body.1.rdb1.conv5.weight
# generator.body.1.rdb1.conv5.bias
# generator.body.1.rdb2.conv1.weight
# generator.body.1.rdb2.conv1.bias
# generator.body.1.rdb2.conv2.weight
# generator.body.1.rdb2.conv2.bias
# generator.body.1.rdb2.conv3.weight
# generator.body.1.rdb2.conv3.bias
# generator.body.1.rdb2.conv4.weight
# generator.body.1.rdb2.conv4.bias
# generator.body.1.rdb2.conv5.weight
# generator.body.1.rdb2.conv5.bias
# generator.body.1.rdb3.conv1.weight
# generator.body.1.rdb3.conv1.bias
# generator.body.1.rdb3.conv2.weight
# generator.body.1.rdb3.conv2.bias
# generator.body.1.rdb3.conv3.weight
# generator.body.1.rdb3.conv3.bias
# generator.body.1.rdb3.conv4.weight
# generator.body.1.rdb3.conv4.bias
# generator.body.1.rdb3.conv5.weight
# generator.body.1.rdb3.conv5.bias
# generator.body.2.rdb1.conv1.weight
# generator.body.2.rdb1.conv1.bias
# generator.body.2.rdb1.conv2.weight
# generator.body.2.rdb1.conv2.bias
# generator.body.2.rdb1.conv3.weight
# generator.body.2.rdb1.conv3.bias
# generator.body.2.rdb1.conv4.weight
# generator.body.2.rdb1.conv4.bias
# generator.body.2.rdb1.conv5.weight
# generator.body.2.rdb1.conv5.bias
# generator.body.2.rdb2.conv1.weight
# generator.body.2.rdb2.conv1.bias
# generator.body.2.rdb2.conv2.weight
# generator.body.2.rdb2.conv2.bias
# generator.body.2.rdb2.conv3.weight
# generator.body.2.rdb2.conv3.bias
# generator.body.2.rdb2.conv4.weight
# generator.body.2.rdb2.conv4.bias
# generator.body.2.rdb2.conv5.weight
# generator.body.2.rdb2.conv5.bias
# generator.body.2.rdb3.conv1.weight
# generator.body.2.rdb3.conv1.bias
# generator.body.2.rdb3.conv2.weight
# generator.body.2.rdb3.conv2.bias
# generator.body.2.rdb3.conv3.weight
# generator.body.2.rdb3.conv3.bias
# generator.body.2.rdb3.conv4.weight
# generator.body.2.rdb3.conv4.bias
# generator.body.2.rdb3.conv5.weight
# generator.body.2.rdb3.conv5.bias
# generator.body.3.rdb1.conv1.weight
# generator.body.3.rdb1.conv1.bias
# generator.body.3.rdb1.conv2.weight
# generator.body.3.rdb1.conv2.bias
# generator.body.3.rdb1.conv3.weight
# generator.body.3.rdb1.conv3.bias
# generator.body.3.rdb1.conv4.weight
# generator.body.3.rdb1.conv4.bias
# generator.body.3.rdb1.conv5.weight
# generator.body.3.rdb1.conv5.bias
# generator.body.3.rdb2.conv1.weight
# generator.body.3.rdb2.conv1.bias
# generator.body.3.rdb2.conv2.weight
# generator.body.3.rdb2.conv2.bias
# generator.body.3.rdb2.conv3.weight
# generator.body.3.rdb2.conv3.bias
# generator.body.3.rdb2.conv4.weight
# generator.body.3.rdb2.conv4.bias
# generator.body.3.rdb2.conv5.weight
# generator.body.3.rdb2.conv5.bias
# generator.body.3.rdb3.conv1.weight
# generator.body.3.rdb3.conv1.bias
# generator.body.3.rdb3.conv2.weight
# generator.body.3.rdb3.conv2.bias
# generator.body.3.rdb3.conv3.weight
# generator.body.3.rdb3.conv3.bias
# generator.body.3.rdb3.conv4.weight
# generator.body.3.rdb3.conv4.bias
# generator.body.3.rdb3.conv5.weight
# generator.body.3.rdb3.conv5.bias
# generator.body.4.rdb1.conv1.weight
# generator.body.4.rdb1.conv1.bias
# generator.body.4.rdb1.conv2.weight
# generator.body.4.rdb1.conv2.bias
# generator.body.4.rdb1.conv3.weight
# generator.body.4.rdb1.conv3.bias
# generator.body.4.rdb1.conv4.weight
# generator.body.4.rdb1.conv4.bias
# generator.body.4.rdb1.conv5.weight
# generator.body.4.rdb1.conv5.bias
# generator.body.4.rdb2.conv1.weight
# generator.body.4.rdb2.conv1.bias
# generator.body.4.rdb2.conv2.weight
# generator.body.4.rdb2.conv2.bias
# generator.body.4.rdb2.conv3.weight
# generator.body.4.rdb2.conv3.bias
# generator.body.4.rdb2.conv4.weight
# generator.body.4.rdb2.conv4.bias
# generator.body.4.rdb2.conv5.weight
# generator.body.4.rdb2.conv5.bias
# generator.body.4.rdb3.conv1.weight
# generator.body.4.rdb3.conv1.bias
# generator.body.4.rdb3.conv2.weight
# generator.body.4.rdb3.conv2.bias
# generator.body.4.rdb3.conv3.weight
# generator.body.4.rdb3.conv3.bias
# generator.body.4.rdb3.conv4.weight
# generator.body.4.rdb3.conv4.bias
# generator.body.4.rdb3.conv5.weight
# generator.body.4.rdb3.conv5.bias
# generator.body.5.rdb1.conv1.weight
# generator.body.5.rdb1.conv1.bias
# generator.body.5.rdb1.conv2.weight
# generator.body.5.rdb1.conv2.bias
# generator.body.5.rdb1.conv3.weight
# generator.body.5.rdb1.conv3.bias
# generator.body.5.rdb1.conv4.weight
# generator.body.5.rdb1.conv4.bias
# generator.body.5.rdb1.conv5.weight
# generator.body.5.rdb1.conv5.bias
# generator.body.5.rdb2.conv1.weight
# generator.body.5.rdb2.conv1.bias
# generator.body.5.rdb2.conv2.weight
# generator.body.5.rdb2.conv2.bias
# generator.body.5.rdb2.conv3.weight
# generator.body.5.rdb2.conv3.bias
# generator.body.5.rdb2.conv4.weight
# generator.body.5.rdb2.conv4.bias
# generator.body.5.rdb2.conv5.weight
# generator.body.5.rdb2.conv5.bias
# generator.body.5.rdb3.conv1.weight
# generator.body.5.rdb3.conv1.bias
# generator.body.5.rdb3.conv2.weight
# generator.body.5.rdb3.conv2.bias
# generator.body.5.rdb3.conv3.weight
# generator.body.5.rdb3.conv3.bias
# generator.body.5.rdb3.conv4.weight
# generator.body.5.rdb3.conv4.bias
# generator.body.5.rdb3.conv5.weight
# generator.body.5.rdb3.conv5.bias
# generator.body.6.rdb1.conv1.weight
# generator.body.6.rdb1.conv1.bias
# generator.body.6.rdb1.conv2.weight
# generator.body.6.rdb1.conv2.bias
# generator.body.6.rdb1.conv3.weight
# generator.body.6.rdb1.conv3.bias
# generator.body.6.rdb1.conv4.weight
# generator.body.6.rdb1.conv4.bias
# generator.body.6.rdb1.conv5.weight
# generator.body.6.rdb1.conv5.bias
# generator.body.6.rdb2.conv1.weight
# generator.body.6.rdb2.conv1.bias
# generator.body.6.rdb2.conv2.weight
# generator.body.6.rdb2.conv2.bias
# generator.body.6.rdb2.conv3.weight
# generator.body.6.rdb2.conv3.bias
# generator.body.6.rdb2.conv4.weight
# generator.body.6.rdb2.conv4.bias
# generator.body.6.rdb2.conv5.weight
# generator.body.6.rdb2.conv5.bias
# generator.body.6.rdb3.conv1.weight
# generator.body.6.rdb3.conv1.bias
# generator.body.6.rdb3.conv2.weight
# generator.body.6.rdb3.conv2.bias
# generator.body.6.rdb3.conv3.weight
# generator.body.6.rdb3.conv3.bias
# generator.body.6.rdb3.conv4.weight
# generator.body.6.rdb3.conv4.bias
# generator.body.6.rdb3.conv5.weight
# generator.body.6.rdb3.conv5.bias
# generator.body.7.rdb1.conv1.weight
# generator.body.7.rdb1.conv1.bias
# generator.body.7.rdb1.conv2.weight
# generator.body.7.rdb1.conv2.bias
# generator.body.7.rdb1.conv3.weight
# generator.body.7.rdb1.conv3.bias
# generator.body.7.rdb1.conv4.weight
# generator.body.7.rdb1.conv4.bias
# generator.body.7.rdb1.conv5.weight
# generator.body.7.rdb1.conv5.bias
# generator.body.7.rdb2.conv1.weight
# generator.body.7.rdb2.conv1.bias
# generator.body.7.rdb2.conv2.weight
# generator.body.7.rdb2.conv2.bias
# generator.body.7.rdb2.conv3.weight
# generator.body.7.rdb2.conv3.bias
# generator.body.7.rdb2.conv4.weight
# generator.body.7.rdb2.conv4.bias
# generator.body.7.rdb2.conv5.weight
# generator.body.7.rdb2.conv5.bias
# generator.body.7.rdb3.conv1.weight
# generator.body.7.rdb3.conv1.bias
# generator.body.7.rdb3.conv2.weight
# generator.body.7.rdb3.conv2.bias
# generator.body.7.rdb3.conv3.weight
# generator.body.7.rdb3.conv3.bias
# generator.body.7.rdb3.conv4.weight
# generator.body.7.rdb3.conv4.bias
# generator.body.7.rdb3.conv5.weight
# generator.body.7.rdb3.conv5.bias
# generator.body.8.rdb1.conv1.weight
# generator.body.8.rdb1.conv1.bias
# generator.body.8.rdb1.conv2.weight
# generator.body.8.rdb1.conv2.bias
# generator.body.8.rdb1.conv3.weight
# generator.body.8.rdb1.conv3.bias
# generator.body.8.rdb1.conv4.weight
# generator.body.8.rdb1.conv4.bias
# generator.body.8.rdb1.conv5.weight
# generator.body.8.rdb1.conv5.bias
# generator.body.8.rdb2.conv1.weight
# generator.body.8.rdb2.conv1.bias
# generator.body.8.rdb2.conv2.weight
# generator.body.8.rdb2.conv2.bias
# generator.body.8.rdb2.conv3.weight
# generator.body.8.rdb2.conv3.bias
# generator.body.8.rdb2.conv4.weight
# generator.body.8.rdb2.conv4.bias
# generator.body.8.rdb2.conv5.weight
# generator.body.8.rdb2.conv5.bias
# generator.body.8.rdb3.conv1.weight
# generator.body.8.rdb3.conv1.bias
# generator.body.8.rdb3.conv2.weight
# generator.body.8.rdb3.conv2.bias
# generator.body.8.rdb3.conv3.weight
# generator.body.8.rdb3.conv3.bias
# generator.body.8.rdb3.conv4.weight
# generator.body.8.rdb3.conv4.bias
# generator.body.8.rdb3.conv5.weight
# generator.body.8.rdb3.conv5.bias
# generator.body.9.rdb1.conv1.weight
# generator.body.9.rdb1.conv1.bias
# generator.body.9.rdb1.conv2.weight
# generator.body.9.rdb1.conv2.bias
# generator.body.9.rdb1.conv3.weight
# generator.body.9.rdb1.conv3.bias
# generator.body.9.rdb1.conv4.weight
# generator.body.9.rdb1.conv4.bias
# generator.body.9.rdb1.conv5.weight
# generator.body.9.rdb1.conv5.bias
# generator.body.9.rdb2.conv1.weight
# generator.body.9.rdb2.conv1.bias
# generator.body.9.rdb2.conv2.weight
# generator.body.9.rdb2.conv2.bias
# generator.body.9.rdb2.conv3.weight
# generator.body.9.rdb2.conv3.bias
# generator.body.9.rdb2.conv4.weight
# generator.body.9.rdb2.conv4.bias
# generator.body.9.rdb2.conv5.weight
# generator.body.9.rdb2.conv5.bias
# generator.body.9.rdb3.conv1.weight
# generator.body.9.rdb3.conv1.bias
# generator.body.9.rdb3.conv2.weight
# generator.body.9.rdb3.conv2.bias
# generator.body.9.rdb3.conv3.weight
# generator.body.9.rdb3.conv3.bias
# generator.body.9.rdb3.conv4.weight
# generator.body.9.rdb3.conv4.bias
# generator.body.9.rdb3.conv5.weight
# generator.body.9.rdb3.conv5.bias
# generator.body.10.rdb1.conv1.weight
# generator.body.10.rdb1.conv1.bias
# generator.body.10.rdb1.conv2.weight
# generator.body.10.rdb1.conv2.bias
# generator.body.10.rdb1.conv3.weight
# generator.body.10.rdb1.conv3.bias
# generator.body.10.rdb1.conv4.weight
# generator.body.10.rdb1.conv4.bias
# generator.body.10.rdb1.conv5.weight
# generator.body.10.rdb1.conv5.bias
# generator.body.10.rdb2.conv1.weight
# generator.body.10.rdb2.conv1.bias
# generator.body.10.rdb2.conv2.weight
# generator.body.10.rdb2.conv2.bias
# generator.body.10.rdb2.conv3.weight
# generator.body.10.rdb2.conv3.bias
# generator.body.10.rdb2.conv4.weight
# generator.body.10.rdb2.conv4.bias
# generator.body.10.rdb2.conv5.weight
# generator.body.10.rdb2.conv5.bias
# generator.body.10.rdb3.conv1.weight
# generator.body.10.rdb3.conv1.bias
# generator.body.10.rdb3.conv2.weight
# generator.body.10.rdb3.conv2.bias
# generator.body.10.rdb3.conv3.weight
# generator.body.10.rdb3.conv3.bias
# generator.body.10.rdb3.conv4.weight
# generator.body.10.rdb3.conv4.bias
# generator.body.10.rdb3.conv5.weight
# generator.body.10.rdb3.conv5.bias
# generator.body.11.rdb1.conv1.weight
# generator.body.11.rdb1.conv1.bias
# generator.body.11.rdb1.conv2.weight
# generator.body.11.rdb1.conv2.bias
# generator.body.11.rdb1.conv3.weight
# generator.body.11.rdb1.conv3.bias
# generator.body.11.rdb1.conv4.weight
# generator.body.11.rdb1.conv4.bias
# generator.body.11.rdb1.conv5.weight
# generator.body.11.rdb1.conv5.bias
# generator.body.11.rdb2.conv1.weight
# generator.body.11.rdb2.conv1.bias
# generator.body.11.rdb2.conv2.weight
# generator.body.11.rdb2.conv2.bias
# generator.body.11.rdb2.conv3.weight
# generator.body.11.rdb2.conv3.bias
# generator.body.11.rdb2.conv4.weight
# generator.body.11.rdb2.conv4.bias
# generator.body.11.rdb2.conv5.weight
# generator.body.11.rdb2.conv5.bias
# generator.body.11.rdb3.conv1.weight
# generator.body.11.rdb3.conv1.bias
# generator.body.11.rdb3.conv2.weight
# generator.body.11.rdb3.conv2.bias
# generator.body.11.rdb3.conv3.weight
# generator.body.11.rdb3.conv3.bias
# generator.body.11.rdb3.conv4.weight
# generator.body.11.rdb3.conv4.bias
# generator.body.11.rdb3.conv5.weight
# generator.body.11.rdb3.conv5.bias
# generator.body.12.rdb1.conv1.weight
# generator.body.12.rdb1.conv1.bias
# generator.body.12.rdb1.conv2.weight
# generator.body.12.rdb1.conv2.bias
# generator.body.12.rdb1.conv3.weight
# generator.body.12.rdb1.conv3.bias
# generator.body.12.rdb1.conv4.weight
# generator.body.12.rdb1.conv4.bias
# generator.body.12.rdb1.conv5.weight
# generator.body.12.rdb1.conv5.bias
# generator.body.12.rdb2.conv1.weight
# generator.body.12.rdb2.conv1.bias
# generator.body.12.rdb2.conv2.weight
# generator.body.12.rdb2.conv2.bias
# generator.body.12.rdb2.conv3.weight
# generator.body.12.rdb2.conv3.bias
# generator.body.12.rdb2.conv4.weight
# generator.body.12.rdb2.conv4.bias
# generator.body.12.rdb2.conv5.weight
# generator.body.12.rdb2.conv5.bias
# generator.body.12.rdb3.conv1.weight
# generator.body.12.rdb3.conv1.bias
# generator.body.12.rdb3.conv2.weight
# generator.body.12.rdb3.conv2.bias
# generator.body.12.rdb3.conv3.weight
# generator.body.12.rdb3.conv3.bias
# generator.body.12.rdb3.conv4.weight
# generator.body.12.rdb3.conv4.bias
# generator.body.12.rdb3.conv5.weight
# generator.body.12.rdb3.conv5.bias
# generator.body.13.rdb1.conv1.weight
# generator.body.13.rdb1.conv1.bias
# generator.body.13.rdb1.conv2.weight
# generator.body.13.rdb1.conv2.bias
# generator.body.13.rdb1.conv3.weight
# generator.body.13.rdb1.conv3.bias
# generator.body.13.rdb1.conv4.weight
# generator.body.13.rdb1.conv4.bias
# generator.body.13.rdb1.conv5.weight
# generator.body.13.rdb1.conv5.bias
# generator.body.13.rdb2.conv1.weight
# generator.body.13.rdb2.conv1.bias
# generator.body.13.rdb2.conv2.weight
# generator.body.13.rdb2.conv2.bias
# generator.body.13.rdb2.conv3.weight
# generator.body.13.rdb2.conv3.bias
# generator.body.13.rdb2.conv4.weight
# generator.body.13.rdb2.conv4.bias
# generator.body.13.rdb2.conv5.weight
# generator.body.13.rdb2.conv5.bias
# generator.body.13.rdb3.conv1.weight
# generator.body.13.rdb3.conv1.bias
# generator.body.13.rdb3.conv2.weight
# generator.body.13.rdb3.conv2.bias
# generator.body.13.rdb3.conv3.weight
# generator.body.13.rdb3.conv3.bias
# generator.body.13.rdb3.conv4.weight
# generator.body.13.rdb3.conv4.bias
# generator.body.13.rdb3.conv5.weight
# generator.body.13.rdb3.conv5.bias
# generator.body.14.rdb1.conv1.weight
# generator.body.14.rdb1.conv1.bias
# generator.body.14.rdb1.conv2.weight
# generator.body.14.rdb1.conv2.bias
# generator.body.14.rdb1.conv3.weight
# generator.body.14.rdb1.conv3.bias
# generator.body.14.rdb1.conv4.weight
# generator.body.14.rdb1.conv4.bias
# generator.body.14.rdb1.conv5.weight
# generator.body.14.rdb1.conv5.bias
# generator.body.14.rdb2.conv1.weight
# generator.body.14.rdb2.conv1.bias
# generator.body.14.rdb2.conv2.weight
# generator.body.14.rdb2.conv2.bias
# generator.body.14.rdb2.conv3.weight
# generator.body.14.rdb2.conv3.bias
# generator.body.14.rdb2.conv4.weight
# generator.body.14.rdb2.conv4.bias
# generator.body.14.rdb2.conv5.weight
# generator.body.14.rdb2.conv5.bias
# generator.body.14.rdb3.conv1.weight
# generator.body.14.rdb3.conv1.bias
# generator.body.14.rdb3.conv2.weight
# generator.body.14.rdb3.conv2.bias
# generator.body.14.rdb3.conv3.weight
# generator.body.14.rdb3.conv3.bias
# generator.body.14.rdb3.conv4.weight
# generator.body.14.rdb3.conv4.bias
# generator.body.14.rdb3.conv5.weight
# generator.body.14.rdb3.conv5.bias
# generator.body.15.rdb1.conv1.weight
# generator.body.15.rdb1.conv1.bias
# generator.body.15.rdb1.conv2.weight
# generator.body.15.rdb1.conv2.bias
# generator.body.15.rdb1.conv3.weight
# generator.body.15.rdb1.conv3.bias
# generator.body.15.rdb1.conv4.weight
# generator.body.15.rdb1.conv4.bias
# generator.body.15.rdb1.conv5.weight
# generator.body.15.rdb1.conv5.bias
# generator.body.15.rdb2.conv1.weight
# generator.body.15.rdb2.conv1.bias
# generator.body.15.rdb2.conv2.weight
# generator.body.15.rdb2.conv2.bias
# generator.body.15.rdb2.conv3.weight
# generator.body.15.rdb2.conv3.bias
# generator.body.15.rdb2.conv4.weight
# generator.body.15.rdb2.conv4.bias
# generator.body.15.rdb2.conv5.weight
# generator.body.15.rdb2.conv5.bias
# generator.body.15.rdb3.conv1.weight
# generator.body.15.rdb3.conv1.bias
# generator.body.15.rdb3.conv2.weight
# generator.body.15.rdb3.conv2.bias
# generator.body.15.rdb3.conv3.weight
# generator.body.15.rdb3.conv3.bias
# generator.body.15.rdb3.conv4.weight
# generator.body.15.rdb3.conv4.bias
# generator.body.15.rdb3.conv5.weight
# generator.body.15.rdb3.conv5.bias
# generator.body.16.rdb1.conv1.weight
# generator.body.16.rdb1.conv1.bias
# generator.body.16.rdb1.conv2.weight
# generator.body.16.rdb1.conv2.bias
# generator.body.16.rdb1.conv3.weight
# generator.body.16.rdb1.conv3.bias
# generator.body.16.rdb1.conv4.weight
# generator.body.16.rdb1.conv4.bias
# generator.body.16.rdb1.conv5.weight
# generator.body.16.rdb1.conv5.bias
# generator.body.16.rdb2.conv1.weight
# generator.body.16.rdb2.conv1.bias
# generator.body.16.rdb2.conv2.weight
# generator.body.16.rdb2.conv2.bias
# generator.body.16.rdb2.conv3.weight
# generator.body.16.rdb2.conv3.bias
# generator.body.16.rdb2.conv4.weight
# generator.body.16.rdb2.conv4.bias
# generator.body.16.rdb2.conv5.weight
# generator.body.16.rdb2.conv5.bias
# generator.body.16.rdb3.conv1.weight
# generator.body.16.rdb3.conv1.bias
# generator.body.16.rdb3.conv2.weight
# generator.body.16.rdb3.conv2.bias
# generator.body.16.rdb3.conv3.weight
# generator.body.16.rdb3.conv3.bias
# generator.body.16.rdb3.conv4.weight
# generator.body.16.rdb3.conv4.bias
# generator.body.16.rdb3.conv5.weight
# generator.body.16.rdb3.conv5.bias
# generator.body.17.rdb1.conv1.weight
# generator.body.17.rdb1.conv1.bias
# generator.body.17.rdb1.conv2.weight
# generator.body.17.rdb1.conv2.bias
# generator.body.17.rdb1.conv3.weight
# generator.body.17.rdb1.conv3.bias
# generator.body.17.rdb1.conv4.weight
# generator.body.17.rdb1.conv4.bias
# generator.body.17.rdb1.conv5.weight
# generator.body.17.rdb1.conv5.bias
# generator.body.17.rdb2.conv1.weight
# generator.body.17.rdb2.conv1.bias
# generator.body.17.rdb2.conv2.weight
# generator.body.17.rdb2.conv2.bias
# generator.body.17.rdb2.conv3.weight
# generator.body.17.rdb2.conv3.bias
# generator.body.17.rdb2.conv4.weight
# generator.body.17.rdb2.conv4.bias
# generator.body.17.rdb2.conv5.weight
# generator.body.17.rdb2.conv5.bias
# generator.body.17.rdb3.conv1.weight
# generator.body.17.rdb3.conv1.bias
# generator.body.17.rdb3.conv2.weight
# generator.body.17.rdb3.conv2.bias
# generator.body.17.rdb3.conv3.weight
# generator.body.17.rdb3.conv3.bias
# generator.body.17.rdb3.conv4.weight
# generator.body.17.rdb3.conv4.bias
# generator.body.17.rdb3.conv5.weight
# generator.body.17.rdb3.conv5.bias
# generator.body.18.rdb1.conv1.weight
# generator.body.18.rdb1.conv1.bias
# generator.body.18.rdb1.conv2.weight
# generator.body.18.rdb1.conv2.bias
# generator.body.18.rdb1.conv3.weight
# generator.body.18.rdb1.conv3.bias
# generator.body.18.rdb1.conv4.weight
# generator.body.18.rdb1.conv4.bias
# generator.body.18.rdb1.conv5.weight
# generator.body.18.rdb1.conv5.bias
# generator.body.18.rdb2.conv1.weight
# generator.body.18.rdb2.conv1.bias
# generator.body.18.rdb2.conv2.weight
# generator.body.18.rdb2.conv2.bias
# generator.body.18.rdb2.conv3.weight
# generator.body.18.rdb2.conv3.bias
# generator.body.18.rdb2.conv4.weight
# generator.body.18.rdb2.conv4.bias
# generator.body.18.rdb2.conv5.weight
# generator.body.18.rdb2.conv5.bias
# generator.body.18.rdb3.conv1.weight
# generator.body.18.rdb3.conv1.bias
# generator.body.18.rdb3.conv2.weight
# generator.body.18.rdb3.conv2.bias
# generator.body.18.rdb3.conv3.weight
# generator.body.18.rdb3.conv3.bias
# generator.body.18.rdb3.conv4.weight
# generator.body.18.rdb3.conv4.bias
# generator.body.18.rdb3.conv5.weight
# generator.body.18.rdb3.conv5.bias
# generator.body.19.rdb1.conv1.weight
# generator.body.19.rdb1.conv1.bias
# generator.body.19.rdb1.conv2.weight
# generator.body.19.rdb1.conv2.bias
# generator.body.19.rdb1.conv3.weight
# generator.body.19.rdb1.conv3.bias
# generator.body.19.rdb1.conv4.weight
# generator.body.19.rdb1.conv4.bias
# generator.body.19.rdb1.conv5.weight
# generator.body.19.rdb1.conv5.bias
# generator.body.19.rdb2.conv1.weight
# generator.body.19.rdb2.conv1.bias
# generator.body.19.rdb2.conv2.weight
# generator.body.19.rdb2.conv2.bias
# generator.body.19.rdb2.conv3.weight
# generator.body.19.rdb2.conv3.bias
# generator.body.19.rdb2.conv4.weight
# generator.body.19.rdb2.conv4.bias
# generator.body.19.rdb2.conv5.weight
# generator.body.19.rdb2.conv5.bias
# generator.body.19.rdb3.conv1.weight
# generator.body.19.rdb3.conv1.bias
# generator.body.19.rdb3.conv2.weight
# generator.body.19.rdb3.conv2.bias
# generator.body.19.rdb3.conv3.weight
# generator.body.19.rdb3.conv3.bias
# generator.body.19.rdb3.conv4.weight
# generator.body.19.rdb3.conv4.bias
# generator.body.19.rdb3.conv5.weight
# generator.body.19.rdb3.conv5.bias
# generator.body.20.rdb1.conv1.weight
# generator.body.20.rdb1.conv1.bias
# generator.body.20.rdb1.conv2.weight
# generator.body.20.rdb1.conv2.bias
# generator.body.20.rdb1.conv3.weight
# generator.body.20.rdb1.conv3.bias
# generator.body.20.rdb1.conv4.weight
# generator.body.20.rdb1.conv4.bias
# generator.body.20.rdb1.conv5.weight
# generator.body.20.rdb1.conv5.bias
# generator.body.20.rdb2.conv1.weight
# generator.body.20.rdb2.conv1.bias
# generator.body.20.rdb2.conv2.weight
# generator.body.20.rdb2.conv2.bias
# generator.body.20.rdb2.conv3.weight
# generator.body.20.rdb2.conv3.bias
# generator.body.20.rdb2.conv4.weight
# generator.body.20.rdb2.conv4.bias
# generator.body.20.rdb2.conv5.weight
# generator.body.20.rdb2.conv5.bias
# generator.body.20.rdb3.conv1.weight
# generator.body.20.rdb3.conv1.bias
# generator.body.20.rdb3.conv2.weight
# generator.body.20.rdb3.conv2.bias
# generator.body.20.rdb3.conv3.weight
# generator.body.20.rdb3.conv3.bias
# generator.body.20.rdb3.conv4.weight
# generator.body.20.rdb3.conv4.bias
# generator.body.20.rdb3.conv5.weight
# generator.body.20.rdb3.conv5.bias
# generator.body.21.rdb1.conv1.weight
# generator.body.21.rdb1.conv1.bias
# generator.body.21.rdb1.conv2.weight
# generator.body.21.rdb1.conv2.bias
# generator.body.21.rdb1.conv3.weight
# generator.body.21.rdb1.conv3.bias
# generator.body.21.rdb1.conv4.weight
# generator.body.21.rdb1.conv4.bias
# generator.body.21.rdb1.conv5.weight
# generator.body.21.rdb1.conv5.bias
# generator.body.21.rdb2.conv1.weight
# generator.body.21.rdb2.conv1.bias
# generator.body.21.rdb2.conv2.weight
# generator.body.21.rdb2.conv2.bias
# generator.body.21.rdb2.conv3.weight
# generator.body.21.rdb2.conv3.bias
# generator.body.21.rdb2.conv4.weight
# generator.body.21.rdb2.conv4.bias
# generator.body.21.rdb2.conv5.weight
# generator.body.21.rdb2.conv5.bias
# generator.body.21.rdb3.conv1.weight
# generator.body.21.rdb3.conv1.bias
# generator.body.21.rdb3.conv2.weight
# generator.body.21.rdb3.conv2.bias
# generator.body.21.rdb3.conv3.weight
# generator.body.21.rdb3.conv3.bias
# generator.body.21.rdb3.conv4.weight
# generator.body.21.rdb3.conv4.bias
# generator.body.21.rdb3.conv5.weight
# generator.body.21.rdb3.conv5.bias
# generator.body.22.rdb1.conv1.weight
# generator.body.22.rdb1.conv1.bias
# generator.body.22.rdb1.conv2.weight
# generator.body.22.rdb1.conv2.bias
# generator.body.22.rdb1.conv3.weight
# generator.body.22.rdb1.conv3.bias
# generator.body.22.rdb1.conv4.weight
# generator.body.22.rdb1.conv4.bias
# generator.body.22.rdb1.conv5.weight
# generator.body.22.rdb1.conv5.bias
# generator.body.22.rdb2.conv1.weight
# generator.body.22.rdb2.conv1.bias
# generator.body.22.rdb2.conv2.weight
# generator.body.22.rdb2.conv2.bias
# generator.body.22.rdb2.conv3.weight
# generator.body.22.rdb2.conv3.bias
# generator.body.22.rdb2.conv4.weight
# generator.body.22.rdb2.conv4.bias
# generator.body.22.rdb2.conv5.weight
# generator.body.22.rdb2.conv5.bias
# generator.body.22.rdb3.conv1.weight
# generator.body.22.rdb3.conv1.bias
# generator.body.22.rdb3.conv2.weight
# generator.body.22.rdb3.conv2.bias
# generator.body.22.rdb3.conv3.weight
# generator.body.22.rdb3.conv3.bias
# generator.body.22.rdb3.conv4.weight
# generator.body.22.rdb3.conv4.bias
# generator.body.22.rdb3.conv5.weight
# generator.body.22.rdb3.conv5.bias
# generator.conv_body.weight
# generator.conv_body.bias
# generator.conv_up1.weight
# generator.conv_up1.bias
# generator.conv_up2.weight
# generator.conv_up2.bias
# generator.conv_hr.weight
# generator.conv_hr.bias
# generator.conv_last.weight
# generator.conv_last.bias

# %% [markdown]
# Interpolate with coefficient 0.8.
#
# It merely performs a linear combination on the two network parameters.

# %%
net_esrgan = torch.load('checkpoints/esrgan_x4c64b23g32_1x16_400k_div2k_20200508-f8ccaf3b.pth')
alpha = 0.8
interpolated_net = {'meta': f'interpolated network with alpha {alpha}', 'state_dict': dict()}
for key, value in net_rrdb_net['state_dict'].items():
  interpolated_net['state_dict'][key] = alpha * net_rrdb_net['state_dict'][key] + (1-alpha) * net_esrgan['state_dict'][key]

torch.save(interpolated_net, './interpolated_net.pth')

# %% [markdown]
# ## Inference with the interpolated network

# %%
config = 'configs/restorers/esrgan/esrgan_x4c64b23g32_g1_400k_div2k.py'
checkpoint = 'interpolated_net.pth'
img_path = 'data/baboon_x4.png'
save_path = 'results/baboon_ESRGAN_interpolated.png'

model = init_model(
        config, checkpoint, device=torch.device('cuda'))

output = restoration_inference(model, img_path)
output = tensor2img(output)

mmcv.imwrite(output, save_path)

# visualize 
img_interp = mmcv.imread('results/baboon_ESRGAN_interpolated.png', channel_order='rgb')

fig = plt.figure(figsize=(18, 16))
ax1 = fig.add_subplot(1, 1, 1)
ax1.axis('off')
ax1.imshow(img_interp)
# Out:
# 2022-03-20 07:07:33,694 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: interpolated_net.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias

# %% [markdown]
# Cannot see the difference? Now let's do some fancy work!
#
# Let's interpolate between two networks with an interval of 0.05.

# %%
import numpy as np
for alpha in list(np.arange(0, 1.05, 0.05)):
    print(f'Interpolating with alpha = {alpha:.2f}...')
    interpolated_net = {'meta': f'interpolated network with alpha {alpha}', 'state_dict': dict()}
    for key, value in net_rrdb_net['state_dict'].items():
        interpolated_net['state_dict'][key] = alpha * net_rrdb_net['state_dict'][key] + (1-alpha) * net_esrgan['state_dict'][key]

    torch.save(interpolated_net, f'./interpolated_net_{int(alpha*100):03d}.pth')
# Out:
# Interpolating with alpha = 0.00...
# Interpolating with alpha = 0.05...
# Interpolating with alpha = 0.10...
# Interpolating with alpha = 0.15...
# Interpolating with alpha = 0.20...
# Interpolating with alpha = 0.25...
# Interpolating with alpha = 0.30...
# Interpolating with alpha = 0.35...
# Interpolating with alpha = 0.40...
# Interpolating with alpha = 0.45...
# Interpolating with alpha = 0.50...
# Interpolating with alpha = 0.55...
# Interpolating with alpha = 0.60...
# Interpolating with alpha = 0.65...
# Interpolating with alpha = 0.70...
# Interpolating with alpha = 0.75...
# Interpolating with alpha = 0.80...
# Interpolating with alpha = 0.85...
# Interpolating with alpha = 0.90...
# Interpolating with alpha = 0.95...
# Interpolating with alpha = 1.00...

# %%
import mmcv
import torch
from mmedit.apis import init_model, restoration_inference
from mmedit.core import tensor2img

config = 'configs/restorers/esrgan/esrgan_x4c64b23g32_g1_400k_div2k.py'
img_path = 'data/baboon_x4.png'
for alpha in list(np.arange(0, 1.05, 0.05)):
    checkpoint = f'./interpolated_net_{int(alpha*100):03d}.pth'
    print(f'Inference with {checkpoint}...')
    save_path = f'results/baboon_interpolated_{int(alpha*100):03d}.png'

    model = init_model(
            config, checkpoint, device=torch.device('cuda'))

    output = restoration_inference(model, img_path)
    output = tensor2img(output)

    mmcv.imwrite(output, save_path)
# Out:
# Inference with ./interpolated_net_000.pth...
# 2022-03-20 07:07:45,183 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_000.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_005.pth...
# 2022-03-20 07:07:49,546 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_005.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_010.pth...
# 2022-03-20 07:07:53,933 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_010.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_015.pth...
# 2022-03-20 07:07:58,087 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_015.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_020.pth...
# 2022-03-20 07:08:02,235 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_020.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_025.pth...
# 2022-03-20 07:08:06,485 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_025.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_030.pth...
# 2022-03-20 07:08:11,350 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_030.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_035.pth...
# 2022-03-20 07:08:15,566 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_035.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_040.pth...
# 2022-03-20 07:08:19,672 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_040.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_045.pth...
# 2022-03-20 07:08:23,787 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_045.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_050.pth...
# 2022-03-20 07:08:27,942 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_050.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_055.pth...
# 2022-03-20 07:08:32,186 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_055.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_060.pth...
# 2022-03-20 07:08:36,360 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_060.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_065.pth...
# 2022-03-20 07:08:40,544 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_065.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_070.pth...
# 2022-03-20 07:08:44,798 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_070.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_075.pth...
# 2022-03-20 07:08:48,985 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_075.pth
# ...
#
# Inference with ./interpolated_net_080.pth...
# 2022-03-20 07:08:53,120 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_080.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_085.pth...
# 2022-03-20 07:08:57,264 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_085.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_090.pth...
# 2022-03-20 07:09:01,397 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_090.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_095.pth...
# 2022-03-20 07:09:05,506 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_095.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias
#
# Inference with ./interpolated_net_100.pth...
# 2022-03-20 07:09:09,607 - mmedit - INFO - load checkpoint from torchvision path: torchvision://vgg19
# load checkpoint from local path: ./interpolated_net_100.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: discriminator.conv0_0.weight, discriminator.conv0_0.bias, discriminator.conv0_1.weight, discriminator.bn0_1.weight, discriminator.bn0_1.bias, discriminator.bn0_1.running_mean, discriminator.bn0_1.running_var, discriminator.conv1_0.weight, discriminator.bn1_0.weight, discriminator.bn1_0.bias, discriminator.bn1_0.running_mean, discriminator.bn1_0.running_var, discriminator.conv1_1.weight, discriminator.bn1_1.weight, discriminator.bn1_1.bias, discriminator.bn1_1.running_mean, discriminator.bn1_1.running_var, discriminator.conv2_0.weight, discriminator.bn2_0.weight, discriminator.bn2_0.bias, discriminator.bn2_0.running_mean, discriminator.bn2_0.running_var, discriminator.conv2_1.weight, discriminator.bn2_1.weight, discriminator.bn2_1.bias, discriminator.bn2_1.running_mean, discriminator.bn2_1.running_var, discriminator.conv3_0.weight, discriminator.bn3_0.weight, discriminator.bn3_0.bias, discriminator.bn3_0.running_mean, discriminator.bn3_0.running_var, discriminator.conv3_1.weight, discriminator.bn3_1.weight, discriminator.bn3_1.bias, discriminator.bn3_1.running_mean, discriminator.bn3_1.running_var, discriminator.conv4_0.weight, discriminator.bn4_0.weight, discriminator.bn4_0.bias, discriminator.bn4_0.running_mean, discriminator.bn4_0.running_var, discriminator.conv4_1.weight, discriminator.bn4_1.weight, discriminator.bn4_1.bias, discriminator.bn4_1.running_mean, discriminator.bn4_1.running_var, discriminator.linear1.weight, discriminator.linear1.bias, discriminator.linear2.weight, discriminator.linear2.bias, perceptual_loss.vgg.mean, perceptual_loss.vgg.std, perceptual_loss.vgg.vgg_layers.0.weight, perceptual_loss.vgg.vgg_layers.0.bias, perceptual_loss.vgg.vgg_layers.2.weight, perceptual_loss.vgg.vgg_layers.2.bias, perceptual_loss.vgg.vgg_layers.5.weight, perceptual_loss.vgg.vgg_layers.5.bias, perceptual_loss.vgg.vgg_layers.7.weight, perceptual_loss.vgg.vgg_layers.7.bias, perceptual_loss.vgg.vgg_layers.10.weight, perceptual_loss.vgg.vgg_layers.10.bias, perceptual_loss.vgg.vgg_layers.12.weight, perceptual_loss.vgg.vgg_layers.12.bias, perceptual_loss.vgg.vgg_layers.14.weight, perceptual_loss.vgg.vgg_layers.14.bias, perceptual_loss.vgg.vgg_layers.16.weight, perceptual_loss.vgg.vgg_layers.16.bias, perceptual_loss.vgg.vgg_layers.19.weight, perceptual_loss.vgg.vgg_layers.19.bias, perceptual_loss.vgg.vgg_layers.21.weight, perceptual_loss.vgg.vgg_layers.21.bias, perceptual_loss.vgg.vgg_layers.23.weight, perceptual_loss.vgg.vgg_layers.23.bias, perceptual_loss.vgg.vgg_layers.25.weight, perceptual_loss.vgg.vgg_layers.25.bias, perceptual_loss.vgg.vgg_layers.28.weight, perceptual_loss.vgg.vgg_layers.28.bias, perceptual_loss.vgg.vgg_layers.30.weight, perceptual_loss.vgg.vgg_layers.30.bias, perceptual_loss.vgg.vgg_layers.32.weight, perceptual_loss.vgg.vgg_layers.32.bias, perceptual_loss.vgg.vgg_layers.34.weight, perceptual_loss.vgg.vgg_layers.34.bias

# %%
# Create a gif image
import imageio
images = []
for alpha in list(np.arange(0, 1.05, 0.05)):
    img_path = f'results/baboon_interpolated_{int(alpha*100):03d}.png'
    images.append(imageio.imread(img_path))
images.reverse()
imageio.mimsave('results/baboon.gif', images)

# %%
from IPython.display import Image
Image(open('results/baboon.gif','rb').read())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# We can now achieve a continuous and smooth transition from PSNR-oriented outputs to GAN effects.

# %% [markdown]
# # What to Do Next?

# %% [markdown]
# - Blind super-resolution: The images captured form the real world have various down-sampling kernels. Blind super-resolution is indeed essential towards real-world applications. [IKC](https://arxiv.org/abs/1904.03377)
# - Video super-resolution: Apply image super-resolution to videos. [EDVR](https://arxiv.org/abs/1905.02716), [BasicVSR](https://ckkelvinchan.github.io/projects/BasicVSR/), [BasicVSR++](https://ckkelvinchan.github.io/projects/BasicVSR++/)
# - Real-World Video Super-Resolution: [RealBasicVSR](https://github.com/ckkelvinchan/RealBasicVSR)
# - Metrics: Metrics are important for perceptual SR. [LPIPS](https://arxiv.org/pdf/1801.03924.pdf)
